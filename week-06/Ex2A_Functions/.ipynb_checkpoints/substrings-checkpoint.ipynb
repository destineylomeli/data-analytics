# %%
# Exercise 2.A Using built-in functions

## Lab 1. Working with names – parsing strings

# %%
test_name = 'John Doe'

# %%
def parse_and_display(name):
    for i in range(len(name)):
        if name[i] == ' ':
            first = name[:i]
            last = name[i+1:]

            print(f"Full name: {name}")
            print(f"First name: {first}")
            print(f"Lasr name: {last}")

# %%
parse_and_display(test_name)

# %%
test_list = ['Grace Flores', 'JB Oinonen', 'Ken Penn']

# %%
parse_and_display(test_list[0]) 
# Output for Grace Flores
# Out:
# Full name: Grace Flores
# First name: Grace
# Lasr name: Flores

# %%
parse_and_display(test_list[1])
# Out:
# Full name: JB Oinonen
# First name: JB
# Lasr name: Oinonen

# %%
parse_and_display(test_list[2])
# Out:
# Full name: Ken Penn
# First name: Ken
# Lasr name: Penn

# %%
parse_and_display('Destiney Lomeli')
# Out:
# Full name: Destiney Lomeli
# First name: Destiney
# Lasr name: Lomeli
