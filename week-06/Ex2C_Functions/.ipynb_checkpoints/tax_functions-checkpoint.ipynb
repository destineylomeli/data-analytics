# %%
# Exercise 2.C tax functions

## Lab 3 Creating tax calculation functions

# %% [markdown]
# # Get Social and Medicare Tax

# %%
def get_soc_sec_tax(gross_pay):
    return gross_pay * 0.062

# %%
def get_medicare_tax(gross_pay):
    return gross_pay * 0.0145

# %% [markdown]
# # Get Federal Tax

# %%
def get_federal_tax(gross_pay, withholding_code):
    
    if withholding_code == 0:
        tax_rate = 0.23

    elif withholding_code == 1:
        tax_rate = 0.21

    elif withholding_code == 2:
        tax_rate = 0.195

    elif withholding_code == 3:
        tax_rate = 0.185

    else: 
        tax_rate = 0.18 - ((withholding_code - 4) * 0.005)

        return gross_pay * tax_rate

# %% [markdown]
# # Test Functions

# %%
gross_pay = 750

print("Social Security Tax:", get_soc_sec_tax(gross_pay))
print("Medicare Tax:", get_medicare_tax(gross_pay))
print("Federal Tax:", get_federal_tax(gross_pay, 0))
# Out:
# Social Security Tax: 46.5
# Medicare Tax: 10.875
# Federal Tax: None

# %%
gross_pay = 1550

print("Social Security Tax:", get_soc_sec_tax(gross_pay))
print("Medicare Tax:", get_medicare_tax(gross_pay))
print("Federal Tax:", get_federal_tax(gross_pay, 2))
# Out:
# Social Security Tax: 96.1
# Medicare Tax: 22.475
# Federal Tax: None

# %%
gross_pay = 1100

print("Social Security Tax:", get_soc_sec_tax(gross_pay))
print("Medicare Tax:", get_medicare_tax(gross_pay))
print("Federal Tax:", get_federal_tax(gross_pay, 5))
# Out:
# Social Security Tax: 68.2
# Medicare Tax: 15.950000000000001
# Federal Tax: 192.5
