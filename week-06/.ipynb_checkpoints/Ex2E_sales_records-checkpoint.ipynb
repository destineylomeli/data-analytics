# %% [markdown]
# # Sales Records Analysis
# ### Author: [Destiney Lomeli]
# ### Exercise 2.E Using functions for analyzing data
# This notebook analyzes a small sales dataset using Python functions.
# Each function takes the full dataset as its first argument.

# %%
sales_data = [
    ("Laptop", "East", 1200.00),
    ("Phone", "West", 850.00),
    ("Tablet", "East", 400.00),
    ("Monitor", "South", 650.00),
    ("Keyboard", "West", 75.00),
    ("Laptop", "South", 1150.00),
    ("Phone", "East", 900.00),
    ("Tablet", "West", 425.00),
    ("Monitor", "East", 680.00),
    ("Keyboard", "South", 80.00),
    ("Laptop", "West", 1300.00),
    ("Phone", "West", 820.00)
]

# %% [markdown]
# # Lab 1. Total Sales By Region

# %%
def region_total(data, region):
    return sum(amt for _, r, amt in data if r == region)

print(region_total(sales_data, "East"))
print(region_total(sales_data, "West"))
print(region_total(sales_data, "South"))
# Out:
# 3180.0
# 3470.0
# 1880.0

# %% [markdown]
# # Lab 2. Count Of Sales By Region

# %%
def region_count(data, region):
    return sum(1 for _, r, amt in data if r == region)

print(region_count(sales_data, "East"))
print(region_count(sales_data, "West"))
print(region_count(sales_data, "South"))
# Out:
# 4
# 5
# 3

# %% [markdown]
# # Lab 3. Average Sale Amount By Region

# %%
def region_average(data, region):
    count = region_count(data, region)

    if count == 0:
        return 0

    return region_total(data, region) / count

print(region_average(sales_data, "East"))
print(region_average(sales_data, "West"))
print(region_average(sales_data, "South"))
print(region_average(sales_data, "North"))
# Out:
# 795.0
# 694.0
# 626.6666666666666
# 0

# %% [markdown]
# # Lab 4. Filter By Sale Amount + Bonus

# %%
def sales_above(data, threshold):
    return [sale for sale in data if sale[2] > threshold]

# %%
results = sales_above(sales_data, 500)

for sale in results:
    print(sale)
# Out:
# ('Laptop', 'East', 1200.0)
# ('Phone', 'West', 850.0)
# ('Monitor', 'South', 650.0)
# ('Laptop', 'South', 1150.0)
# ('Phone', 'East', 900.0)
# ('Monitor', 'East', 680.0)
# ('Laptop', 'West', 1300.0)
# ('Phone', 'West', 820.0)

# %%
def sales_below(data, threshold):
    return [sale for sale in data if sale[2] < threshold]

results = sales_below(sales_data, 500)

for sale in results:
    print(sale)
# Out:
# ('Tablet', 'East', 400.0)
# ('Keyboard', 'West', 75.0)
# ('Tablet', 'West', 425.0)
# ('Keyboard', 'South', 80.0)

# %% [markdown]
# # Lab 5. Top And Bottom Sale

# %%
def top_sale(data):
    return max(data, key=lambda s: s[2])

def bottom_sale(data):
    return min(data, key=lambda s: s[2])

print(top_sale(sales_data))
print(bottom_sale(sales_data))
# Out:
# ('Laptop', 'West', 1300.0)
# ('Keyboard', 'West', 75.0)

# %% [markdown]
# The top sale was a Laptop in the West region for $1300.00.
#
# The bottom sale was a Keyboard in the West region for $75.00

# %% [markdown]
# # Lab 6. Apply A Discount

# %%
def apply_discount(data, discount_pct):
    return list(
        map(
            lambda s: (s[0], s[1], s[2] * (1 - discount_pct)),
            data
        )
    )

# %%
discounted_sales = apply_discount(sales_data, 0.10)

for sale in discounted_sales:
    print(sale)
# Out:
# ('Laptop', 'East', 1080.0)
# ('Phone', 'West', 765.0)
# ('Tablet', 'East', 360.0)
# ('Monitor', 'South', 585.0)
# ('Keyboard', 'West', 67.5)
# ('Laptop', 'South', 1035.0)
# ('Phone', 'East', 810.0)
# ('Tablet', 'West', 382.5)
# ('Monitor', 'East', 612.0)
# ('Keyboard', 'South', 72.0)
# ('Laptop', 'West', 1170.0)
# ('Phone', 'West', 738.0)

# %%
discounted_sales_15 = apply_discount(sales_data, 0.15)

print("Before Discount:")
for sale in sales_data[:3]:
    print(sale)

print("\nAfter 15% Discount:")
for sale in discounted_sales_15[:3]:
    print(sale)
# Out:
# Before Discount:
# ('Laptop', 'East', 1200.0)
# ('Phone', 'West', 850.0)
# ('Tablet', 'East', 400.0)
#
# After 15% Discount:
# ('Laptop', 'East', 1020.0)
# ('Phone', 'West', 722.5)
# ('Tablet', 'East', 340.0)

# %% [markdown]
# # Lab 7. Unique Regions

# %%
def unique_regions(data):
    return sorted(set(region for _, region, _ in data))

# %%
print(unique_regions(sales_data))
# Out:
# ['East', 'South', 'West']

# %% [markdown]
# This function could be useful in a larger program because it helps identify all unique regions in the data set automatically. This can help organize reports, summaries, or filtering data by region without manually typing each region name.

# %% [markdown]
# # Lab 8. Region Summary

# %%
def region_summary(data, region):
    region_data = [s for s in data if s[1] == region]

    total = region_total(data, region)
    count = region_count(data, region)
    average = region_average(data, region)
    top = max(region_data, key=lambda s: s[2])

    print(f"=== {region} Region ===")
    print(f"Records: {count}")
    print(f"Total Sales: ${total:,.2f}")
    print(f"Average Sale: ${average:,.2f}")
    print(f"Top Sale: {top[0]} - ${top[2]:,.2f}")

# %%
region_summary(sales_data, "East")
# Out:
# === East Region ===
# Records: 4
# Total Sales: $3,180.00
# Average Sale: $795.00
# Top Sale: Laptop - $1,200.00

# %% [markdown]
# # Lab 9. Full Sumary

# %%
for region in unique_regions(sales_data):
    region_summary(sales_data, region)
    print()
# Out:
# === East Region ===
# Records: 4
# Total Sales: $3,180.00
# Average Sale: $795.00
# Top Sale: Laptop - $1,200.00
#
# === South Region ===
# Records: 3
# Total Sales: $1,880.00
# Average Sale: $626.67
# Top Sale: Laptop - $1,150.00
#
# === West Region ===
# Records: 5
# Total Sales: $3,470.00
# Average Sale: $694.00
# Top Sale: Laptop - $1,300.00

# %% [markdown]
# In this set of labs, I learned how to create and use Python functions to analyze data. I practiced using loops, lists, generator expressions, lambda functions, map(), filtering data, and calculating totals and averages. I also learned how to organize and summarize data in a clear way using reusable functions.
